# %%
#Instala a versão exata do pacote
# !pip install -q pandas==1.5.3

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ### Manipulando Dados em DataFrames do Pandas

# %%
dados = { 'Estado': ['Santa Catarina', 'Rio de Janeiro', 'Tocantis', 'Bahia', 'Minas Gerais'],
        'Ano': [2004, 2005, 2006, 2007, 2008],
         'Taxa Desemprego': [1.5,1.7,1.6,2.4,2.7]}

# %%
print(dados)
# Out:
# {'Estado': ['Santa Catarina', 'Rio de Janeiro', 'Tocantis', 'Bahia', 'Minas Gerais'], 'Ano': [2004, 2005, 2006, 2007, 2008], 'Taxa Desempregro': [1.5, 1.7, 1.6, 2.4, 2.7]}

# %%
from pandas import DataFrame

# %%
df = DataFrame(dados)

# %%
df.head()
# Out:
#            Estado   Ano  Taxa Desemprego
# 0  Santa Catarina  2004              1.5
# 1  Rio de Janeiro  2005              1.7
# 2        Tocantis  2006              1.6
# 3           Bahia  2007              2.4
# 4    Minas Gerais  2008              2.7

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Reorganizando as Colunas
DataFrame(dados, columns = ['Ano', 'Estado', 'Taxa Desemprego'])
# Out:
#     Ano          Estado  Taxa Desemprego
# 0  2004  Santa Catarina              1.5
# 1  2005  Rio de Janeiro              1.7
# 2  2006        Tocantis              1.6
# 3  2007           Bahia              2.4
# 4  2008    Minas Gerais              2.7

# %%
#Criando outro dataframe com os mesmos dados anteriores e adicionando uma coluna
df2 = DataFrame(dados,
               columns = ['Estado','Taxa Desemprego', 'Taxa Crescimento', 'Ano'],
               index = ['estado1','estado2','estado3','estado4','estado5'])

# %%
df2
# Out:
#                  Estado  Taxa Desemprego Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5              NaN  2004
# estado2  Rio de Janeiro              1.7              NaN  2005
# estado3        Tocantis              1.6              NaN  2006
# estado4           Bahia              2.4              NaN  2007
# estado5    Minas Gerais              2.7              NaN  2008

# %%
df2.values
# Out:
# array([['Santa Catarina', 1.5, nan, 2004],
#        ['Rio de Janeiro', 1.7, nan, 2005],
#        ['Tocantis', 1.6, nan, 2006],
#        ['Bahia', 2.4, nan, 2007],
#        ['Minas Gerais', 2.7, nan, 2008]], dtype=object)

# %%
df2.dtypes
# Out:
# Estado               object
# Taxa Desemprego     float64
# Taxa Crescimento     object
# Ano                   int64
# dtype: object

# %%
df2.columns
# Out:
# Index(['Estado', 'Taxa Desemprego', 'Taxa Crescimento', 'Ano'], dtype='object')

# %%
df2['Estado']
# Out:
# estado1    Santa Catarina
# estado2    Rio de Janeiro
# estado3          Tocantis
# estado4             Bahia
# estado5      Minas Gerais
# Name: Estado, dtype: object

# %%
df2[['Taxa Desemprego','Ano']]
# Out:
#          Taxa Desemprego   Ano
# estado1              1.5  2004
# estado2              1.7  2005
# estado3              1.6  2006
# estado4              2.4  2007
# estado5              2.7  2008

# %%
df2.index
# Out:
# Index(['estado1', 'estado2', 'estado3', 'estado4', 'estado5'], dtype='object')

# %%
df2.filter(items = ['estado3'], axis =0) #axis é o eixo, ou seja, eixo 0
# Out:
#            Estado  Taxa Desemprego Taxa Crescimento   Ano
# estado3  Tocantis              1.6              NaN  2006

# %% [markdown]
# ### Usando Numpy e Pandas para Manipulação de Dados

# %%
df2.head()
# Out:
#                  Estado  Taxa Desemprego Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5              NaN  2004
# estado2  Rio de Janeiro              1.7              NaN  2005
# estado3        Tocantis              1.6              NaN  2006
# estado4           Bahia              2.4              NaN  2007
# estado5    Minas Gerais              2.7              NaN  2008

# %%
df2.describe() #Resumo estatístico do dataframe
# Out:
#        Taxa Desemprego          Ano
# count         5.000000     5.000000
# mean          1.980000  2006.000000
# std           0.535724     1.581139
# min           1.500000  2004.000000
# 25%           1.600000  2005.000000
# 50%           1.700000  2006.000000
# 75%           2.400000  2007.000000
# max           2.700000  2008.000000

# %%
df2.isna() #verificando se tem valores nulos/ausente
# Out:
#          Estado  Taxa Desemprego  Taxa Crescimento    Ano
# estado1   False            False              True  False
# estado2   False            False              True  False
# estado3   False            False              True  False
# estado4   False            False              True  False
# estado5   False            False              True  False

# %%
df2['Taxa Crescimento'].isna
# Out:
# <bound method Series.isna of estado1    NaN
# estado2    NaN
# estado3    NaN
# estado4    NaN
# estado5    NaN
# Name: Taxa Crescimento, dtype: object>

# %%
import numpy as np

# %%
df2['Taxa Crescimento'] = np.arange(5.)

# %%
df2
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5               0.0  2004
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3        Tocantis              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007
# estado5    Minas Gerais              2.7               4.0  2008

# %%
df2['Taxa Crescimento'].isna
# Out:
# <bound method Series.isna of estado1    0.0
# estado2    1.0
# estado3    2.0
# estado4    3.0
# estado5    4.0
# Name: Taxa Crescimento, dtype: float64>

# %%
df2.dtypes
# Out:
# Estado               object
# Taxa Desemprego     float64
# Taxa Crescimento    float64
# Ano                   int64
# dtype: object

# %%
df2.describe()
# Out:
#        Taxa Desemprego  Taxa Crescimento          Ano
# count         5.000000          5.000000     5.000000
# mean          1.980000          2.000000  2006.000000
# std           0.535724          1.581139     1.581139
# min           1.500000          0.000000  2004.000000
# 25%           1.600000          1.000000  2005.000000
# 50%           1.700000          2.000000  2006.000000
# 75%           2.400000          3.000000  2007.000000
# max           2.700000          4.000000  2008.000000

# %% [markdown]
# # Pandas - Slicing DataFrames

# %%
df2
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5               0.0  2004
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3        Tocantis              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007
# estado5    Minas Gerais              2.7               4.0  2008

# %%
df2['estado2':'estado4'] #não é exclusivo, vou pegar os indices estado 2 a estado 4
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3        Tocantis              1.6               2.0  2006
# estado4           Bahia              2.4               3.0  2007

# %%
df2[ df2['Taxa Desemprego'] < 2 ] #pegando na coluna taxa desemprego é menor que 2
# Out:
#                  Estado  Taxa Desemprego  Taxa Crescimento   Ano
# estado1  Santa Catarina              1.5               0.0  2004
# estado2  Rio de Janeiro              1.7               1.0  2005
# estado3        Tocantis              1.6               2.0  2006

# %%
df2[['Estado','Taxa Crescimento']]
# Out:
#                  Estado  Taxa Crescimento
# estado1  Santa Catarina               0.0
# estado2  Rio de Janeiro               1.0
# estado3        Tocantis               2.0
# estado4           Bahia               3.0
# estado5    Minas Gerais               4.0

# %% [markdown]
# ### Pandas - Preenchendo valores ausentes em DataFrames

# %%
#A função fillna() é usada para preencher os valores ausentes. Podemos usar valores especificos ou uma função agregada.
#Para esse exemplo, vai ser considerado a moda, que é justamente o valor que mais se repete.

# %%
dsa_df = pd.read_csv("dataset.csv")

# %%
dsa_df.head(5)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0

# %%
dsa_df.isna().sum() #soma o número de valores ausente, caso exista
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
moda = dsa_df['Quantidade'].value_counts().index[0]

# %%
print(moda)
# Out:
# 3.0

# %%
dsa_df['Quantidade'].fillna(value=moda,inplace=True)

# %%
dsa_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# dtype: int64

# %% [markdown]
# ## Pandas - Query de dados no DataFrame

# %%
#Como dataframes são tabelas, podemos fazer consultas, utilizando o método query.

# %%
#Checando valor de mínimo e máxio da voluna valor_venda
dsa_df.Valor_Venda.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
df2 = dsa_df.query('229 < Valor_Venda < 1000')

# %%
df2.Valor_Venda.describe()
# Out:
# count    1894.000000
# mean      471.347406
# std       202.048123
# min       229.544000
# 25%       302.376000
# 50%       418.308000
# 75%       600.558000
# max       999.980000
# Name: Valor_Venda, dtype: float64

# %%
df3 = df2.query('Valor_Venda > 766')

# %%
df3.head()
# Out:
#           ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 3    US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 7    CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 11   CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 72   US-2015-134026  2015-04-26   JE-15745  Consumer  United States  South
# 117  CA-2015-110457  2015-03-02   DK-13090  Consumer  United States   West
#
#           ID_Produto   Categoria  \
# 3    FUR-TA-10000577   Furniture
# 7    TEC-PH-10002275  Technology
# 11   TEC-PH-10002033  Technology
# 72   FUR-CH-10000513   Furniture
# 117  FUR-TA-10001768   Furniture
#
#                                       Nome_Produto  Valor_Venda  Quantidade
# 3    Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 7                   Mitel 5320 IP Phone VoIP phone     907.1520         6.0
# 11   Konftel 250 Conference phone - Charcoal black     911.4240         4.0
# 72               High-Back Leather Manager's Chair     831.9360         8.0
# 117                Hon Racetrack Conference Tables     787.5300         3.0

# %% [markdown]
# ## Pandas - Verificando Ocorrências

# %%
dsa_df.shape
# Out:
# (9994, 11)

# %%
dsa_df[dsa_df['Quantidade'].isin([5,7,9,8])]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9974  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9977  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9981  CA-2017-163566  2017-08-03   TB-21055     Consumer  United States
# 9982  US-2016-157728  2016-09-22   RC-19960     Consumer  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# 5        West  FUR-FU-10001487        Furniture
# 9        West  OFF-AP-10002892  Office Supplies
# 10       West  FUR-TA-10001539        Furniture
# 14    Central  OFF-AP-10002311  Office Supplies
# ...       ...              ...              ...
# 9974     West  OFF-AR-10004752  Office Supplies
# 9977     West  OFF-FA-10003467  Office Supplies
# 9981     East  OFF-LA-10004484  Office Supplies
# 9982  Central  OFF-PA-10002195  Office Supplies
# 9988    South  TEC-PH-10004006       Technology
#
#                                            Nome_Produto  Valor_Venda  \
# 3         Bretford CR4500 Series Slim Rectangular Table     957.5775
# 5     Eldon Expressions Wood and Plastic Desk Access...      48.8600
# 9                      Belkin F5C206VTEL 6 Outlet Surge     114.9000
# 10             Chromcraft Rectangular Conference Tables    1706.1840
# 14    Holmes Replacement Filter for HEPA Air Cleaner...      68.8100
# ...                                                 ...          ...
# 9974                               Blackstonian Pencils      18.6900
# 9977           Alliance Big Bands Rubber Bands, 12/Pack      13.8600
# 9981                                          Avery 476      16.5200
# 9982  RSVP Cards & Envelopes, Blank White, 8-1/2" X ...      35.5600
# 9988                    Panasonic KX - TS880B Telephone     206.1000
#
#       Quantidade
# 3            5.0
# 5            7.0
# 9            5.0
# 10           9.0
# 14           5.0
# ...          ...
# 9974         7.0
# 9977         7.0
# 9981         5.0
# 9982         7.0
# 9988         5.0
#
# [2351 rows x 11 columns]

# %%
dsa_df[dsa_df['Quantidade'].isin([5,7,9,8])].shape
# Out:
# (2351, 11)

# %%
dsa_df[dsa_df['Quantidade'].isin([5,7,9,8])][:10]
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 21  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 22  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 27  US-2015-150630  2015-09-17   TB-21520     Consumer  United States
# 35  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
# 36  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
#
#      Regiao       ID_Produto        Categoria  \
# 3     South  FUR-TA-10000577        Furniture
# 5      West  FUR-FU-10001487        Furniture
# 9      West  OFF-AP-10002892  Office Supplies
# 10     West  FUR-TA-10001539        Furniture
# 14  Central  OFF-AP-10002311  Office Supplies
# 21  Central  OFF-AR-10000246  Office Supplies
# 22  Central  OFF-AP-10001492  Office Supplies
# 27     East  FUR-BO-10004834        Furniture
# 35  Central  TEC-PH-10004977       Technology
# 36  Central  FUR-FU-10003664        Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 3       Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 5   Eldon Expressions Wood and Plastic Desk Access...      48.8600         7.0
# 9                    Belkin F5C206VTEL 6 Outlet Surge     114.9000         5.0
# 10           Chromcraft Rectangular Conference Tables    1706.1840         9.0
# 14  Holmes Replacement Filter for HEPA Air Cleaner...      68.8100         5.0
# 21                                         Newell 318      19.4600         7.0
# 22        Acco Six-Outlet Power Strip, 4' Cord Length      60.3400         7.0
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...    3083.4300         7.0
# 35                                        GE 30524EE4    1097.5440         7.0
# 36  Electrix Architect's Clamp-On Swing Arm Lamp, ...     190.9200         5.0

# %% [markdown]
# ## Pandas - Operadores Lógicos

# %%
dsa_df[ (dsa_df.Segmento == 'Home Office') & (dsa_df.Regiao == 'West')].head()
# Out:
#           ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais Regiao  \
# 95   US-2017-109484  2017-11-06   RB-19705  Home Office  United States   West
# 128  US-2016-125969  2016-11-06   LS-16975  Home Office  United States   West
# 129  US-2016-125969  2016-11-06   LS-16975  Home Office  United States   West
# 151  CA-2016-158834  2016-03-13   TW-21025  Home Office  United States   West
# 152  CA-2016-158834  2016-03-13   TW-21025  Home Office  United States   West
#
#           ID_Produto        Categoria  \
# 95   OFF-BI-10004738  Office Supplies
# 128  FUR-CH-10001146        Furniture
# 129  FUR-FU-10003773        Furniture
# 151  OFF-AP-10000326  Office Supplies
# 152  TEC-PH-10001254       Technology
#
#                                           Nome_Produto  Valor_Venda  \
# 95   Flexible Leather- Look Classic Collection Ring...        5.682
# 128                           Global Task Chair, Black       81.424
# 129  Eldon Cleatmat Plus Chair Mats for High Pile C...      238.560
# 151  Belkin 7 Outlet SurgeMaster Surge Protector wi...      157.920
# 152           Jabra BIZ 2300 Duo QD Duo Corded Headset      203.184
#
#      Quantidade
# 95          1.0
# 128         2.0
# 129         3.0
# 151         5.0
# 152         2.0

# %%
dsa_df[ (dsa_df.Segmento == 'Home Office') | (dsa_df.Regiao == 'West')].tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 9986  CA-2016-125794  2016-09-29   ML-17410  Consumer  United States   West
# 9990  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9991  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9992  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9993  CA-2017-119914  2017-05-04   CC-12220  Consumer  United States   West
#
#            ID_Produto        Categoria  \
# 9986  TEC-AC-10003399       Technology
# 9990  FUR-FU-10000747        Furniture
# 9991  TEC-PH-10003645       Technology
# 9992  OFF-PA-10004041  Office Supplies
# 9993  OFF-AP-10002684  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...       36.240
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...       91.960
# 9991                              Aastra 57i VoIP phone      258.576
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"       29.600
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...      243.160
#
#       Quantidade
# 9986         1.0
# 9990         2.0
# 9991         2.0
# 9992         4.0
# 9993         2.0

# %%
dsa_df[ (dsa_df.Segmento != 'Home Office') | (dsa_df.Regiao != 'West')].sample(5)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 5538  CA-2015-120551  2015-04-13   SS-20590     Consumer  United States
# 4027  CA-2017-139311  2017-08-11   SF-20965    Corporate  United States
# 5808  CA-2016-149783  2016-09-04   DL-13315     Consumer  United States
# 3906  CA-2015-167010  2015-04-05   VT-21700  Home Office  United States
# 7929  CA-2017-167549  2017-07-25   EM-14200  Home Office  United States
#
#        Regiao       ID_Produto        Categoria  \
# 5538  Central  OFF-BI-10002071  Office Supplies
# 4027  Central  TEC-PH-10001557       Technology
# 5808    South  OFF-AR-10002987  Office Supplies
# 3906     East  FUR-FU-10001468        Furniture
# 7929  Central  FUR-TA-10004767        Furniture
#
#                               Nome_Produto  Valor_Venda  Quantidade
# 5538  Fellowes Black Plastic Comb Bindings       17.430         3.0
# 4027                         Pyle PMP37LED      153.584         2.0
# 5808          Prismacolor Color Pencil Set       31.744         2.0
# 3906  Tenex Antistatic Computer Chair Mats      547.136         4.0
# 7929                  Safco Drafting Table      298.116         6.0

# %% [markdown]
# ## Pandas - Agrupamento Group By

# %%
#Aplicamos o group by
dsa_df[['Segmento','Regiao','Valor_Venda']].groupby(['Segmento','Regiao']).mean()
# Out:
#                      Valor_Venda
# Segmento    Regiao
# Consumer    Central   207.946728
#             East      238.875539
#             South     233.390180
#             West      217.033955
# Corporate   Central   234.763466
#             East      228.516929
#             South     238.992025
#             West      235.265911
# Home Office Central   208.248046
#             East      253.911805
#             South     272.996329
#             West      239.442692

# %% [markdown]
# ##  Pandas - Agregação Múltiplaa com Group By

# %%
#Primeiros extraimos as 3 colunas, agrupo por duas colunas segmento e região e depois faço a agregação por média, dp e cont.
dsa_df[['Segmento','Regiao','Valor_Venda']].groupby(['Segmento','Regiao']).agg(['mean','std','count'])
# Out:
#                     Valor_Venda
#                            mean          std count
# Segmento    Regiao
# Consumer    Central  207.946728   587.906523  1212
#             East     238.875539   633.371169  1469
#             South    233.390180   559.346824   838
#             West     217.033955   551.997547  1672
# Corporate   Central  234.763466   818.947521   673
#             East     228.516929   530.001654   877
#             South    238.992025   586.176947   510
#             West     235.265911   471.288764   960
# Home Office Central  208.248046   371.009180   438
#             East     253.911805   722.777318   502
#             South    272.996329  1404.798466   272
#             West     239.442692   529.242737   571

# %% [markdown]
# ## Pandas - Filtrando DataFrame do Pandas com Base em Strings

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0

# %%
#Filtrando na coluna segmento os valores que iniciam com 'Con'
dsa_df[dsa_df.Segmento.str.startswith('Con')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...      48.8600         7.0

# %%
dsa_df.Segmento.value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segmento, dtype: int64

# %%
#Filtrando na coluna segmento os valores que terminam com 'mer'
dsa_df[dsa_df.Segmento.str.endswith('mer')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...      48.8600         7.0

# %% [markdown]
# ## Pandas - Split de Strings

# %%
dsa_df['ID_Pedido'].head()
# Out:
# 0    CA-2016-152156
# 1    CA-2016-152156
# 2    CA-2016-138688
# 3    US-2015-108966
# 4    US-2015-108966
# Name: ID_Pedido, dtype: object

# %%
#Split da coluna pelo caracter '-'
dsa_df['ID_Pedido'].str.split('-')
# Out:
# 0       [CA, 2016, 152156]
# 1       [CA, 2016, 152156]
# 2       [CA, 2016, 138688]
# 3       [US, 2015, 108966]
# 4       [US, 2015, 108966]
#                ...
# 9989    [CA, 2014, 110422]
# 9990    [CA, 2017, 121258]
# 9991    [CA, 2017, 121258]
# 9992    [CA, 2017, 121258]
# 9993    [CA, 2017, 119914]
# Name: ID_Pedido, Length: 9994, dtype: object

# %%
dsa_df['ID_Pedido'].str.split('-').str[1].head()
# Out:
# 0    2016
# 1    2016
# 2    2016
# 3    2015
# 4    2015
# Name: ID_Pedido, dtype: object

# %%
dsa_df['Ano'] = dsa_df['ID_Pedido'].str.split('-').str[1]

# %%
dsa_df['Id'] = dsa_df['ID_Pedido'].str.split('-').str[2]

# %%
dsa_df['UF'] = dsa_df['ID_Pedido'].str.split('-').str[0]

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
#
#     Ano      Id  UF
# 0  2016  152156  CA
# 1  2016  152156  CA
# 2  2016  138688  CA
# 3  2015  108966  US
# 4  2015  108966  US

# %%
dsa_df['Data_Pedido'].head(3)
# Out:
# 0    2016-11-08
# 1    2016-11-08
# 2    2016-06-12
# Name: Data_Pedido, dtype: object

# %%
#strip vai remover os caracteres lstrip remove a partir do lado esquerdo da string 
dsa_df['Data_Pedido'].str.lstrip('20')
# Out:
# 0       16-11-08
# 1       16-11-08
# 2       16-06-12
# 3       15-10-11
# 4       15-10-11
#           ...
# 9989    14-01-21
# 9990    17-02-26
# 9991    17-02-26
# 9992    17-02-26
# 9993    17-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %% [markdown]
# ## Pandas - Replace

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
#
#     Ano      Id  UF
# 0  2016  152156  CA
# 1  2016  152156  CA
# 2  2016  138688  CA
# 3  2015  108966  US
# 4  2015  108966  US

# %%
dsa_df['ID_Cliente'] = dsa_df['ID_Cliente'].str.replace('CG','AX')

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
#
#     Ano      Id  UF
# 0  2016  152156  CA
# 1  2016  152156  CA
# 2  2016  138688  CA
# 3  2015  108966  US
# 4  2015  108966  US

# %% [markdown]
# ## Pandas - Combinação de Strings

# %%
#Concatenando strings
dsa_df['Pedido_Segmento']= dsa_df['ID_Pedido'].str.cat(dsa_df['Segmento'], sep = '-')

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2.0
#
#     Ano      Id  UF           Pedido_Segmento
# 0  2016  152156  CA   CA-2016-152156-Consumer
# 1  2016  152156  CA   CA-2016-152156-Consumer
# 2  2016  138688  CA  CA-2016-138688-Corporate
# 3  2015  108966  US   US-2015-108966-Consumer
# 4  2015  108966  US   US-2015-108966-Consumer

# %% [markdown]
# ## Construção de Gráficos a Partir de DataFrames do Pandas

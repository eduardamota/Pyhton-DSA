# %%
# !pip install -q seaborn==0.12.2

# %%
# Imports

import random
import numpy as np
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.21.5'

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
mat.__version__
# Out:
# '3.7.1'

# %%
import seaborn as sea

# %% [markdown]
# ## Criando gráficos com Seaborn

# %%
dados = sea.load_dataset("tips")

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Criando gráficos bivariados e univariados usando o joinplot
import seaborn as sns
sns.jointplot(data=dados, x="total_bill", y="tip", kind='reg') #gráfico do tipo reg com uma linha de regressão

# %%
#Metodo lmplot() cria plot com dados e modelos de regressão
sea.lmplot(data = dados, x = "total_bill", y = "tip", col = "smoker") #relação entre duas variáveis com base na variável smoker

# %%
df = pd.DataFrame()

# %%
df['idade'] = random.sample(range(20,100),30)
df['peso'] = random.sample(range(55,150),30)

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    idade  peso
# 0     85   115
# 1     87   102
# 2     26    91
# 3     76   149
# 4     71    87

# %%
#lmplot
sea.lmplot(data=df, x ="idade", y = "peso", fit_reg = True) #fit_reg=true cria um modelo de regressão

# %%
#kdeplot
sea.kdeplot(df.idade) #gráfico de densidade
# Out:
# <Axes: xlabel='idade', ylabel='Density'>

# %%
#distplot
sea.distplot(df.peso) #vai unir o histograma com o gráfico de densidade
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
#Histograma
plt.hist(df.idade, alpha =.3) #o alpha controla a transparencia do gráfico
sea.rugplot(df.idade) #rugas no gráfico, tracinhos
# Out:
# <Axes: xlabel='idade'>

# %%
#Box Plot
sea.boxplot(df.idade, color = 'g')
# Out:
# <Axes: >

# %%
#Violin Plot
sea.violinplot(df.idade)
# Out:
# <Axes: >

# %%
#clustermap
sea.clustermap(df)

# %% [markdown]
# ## Usando Matplotlib, Seaborn, Numpy e Pandas na Criação de gráfico estatístico

# %%
#Valores randômicos
np.random.seed(42)
n = 1000
pct_smokers = 0.2

#Variáveis
flag_fumante = np.random.rand(n) <pct_smokers
idade = np.random.normal(40,10,n)
altura = np.random.normal(170, 10, n)

peso = np.random.normal(70,10,n)

#DataFrame
dados = pd.DataFrame({'altura': altura, 'peso':peso, 'flag_fumante':flag_fumante})

#Cria os dados para a variável flag_fumante
dados['flag_fumante'] = dados['flag_fumante'].map({True:'Fumante',False:'Não Fumante'})

# %%
dados.shape
# Out:
# (1000, 3)

# %%
dados.head()
# Out:
#        altura       peso flag_fumante
# 0  155.936825  78.745171  Não Fumante
# 1  169.168944  63.502348  Não Fumante
# 2  154.952796  57.967991  Não Fumante
# 3  177.600560  59.579556  Não Fumante
# 4  170.824398  65.127971      Fumante

# %%
#Style
sns.set(style = "ticks")

#lmplot
sns.lmplot (x = 'altura',
            y = 'peso',
            data = dados,
            hue = 'flag_fumante',
            palette =['tab:blue', 'tab:orange'],
            height =7
           )

#labels e título
plt.xlabel('Altura(cm)')
plt.ylabel('Peso (kg)')
plt.title('Relação entre Altura e Peso de Fumante e Não Fumante')

#Remove bordas
sns.despine()

#show
plt.show()
